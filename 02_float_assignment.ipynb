# %%
# Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577
nums= 3.14,2.718,1.618,0.577
total=sum(nums)
avg=total/len(nums)
print(avg)
# Out:
# 2.01325

# %%
# Question 2: Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)
fahrenheit=98.6
celsius=(fahrenheit-32)*5/9
print(celsius)
# Out:
# 37.0

# %%
# Question 3: Calculate the compound interest on $1000 at 5.5% for 3 years.
principle=1000
time=3
rate=5.5  ##0.055
amount=principle*(1+0.055)**3
print(amount)
CI=amount-principle
print(CI)
# Out:
# 1174.2413749999998
# 174.24137499999983

# %%
# Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2.
side_1=3.5
side_2=4.2
hypotenuse=(side_1**2 + side_2**2)**0.5
print(hypotenuse)
# Out:
# 5.4671747731346585

# %%
# Question 5: Calculate the volume of a sphere with radius 7.8
radius=7.8
phai=22/7
volume=4/3*phai*radius**3
print(volume)
# Out:
# 1988.5988571428566

# %%
# Question 6: Round 3.14159 to 3 decimal places
num=3.14159
round_=round(num,3)
print(round_)
# Out:
# 3.142

# %%
# Question 7: Calculate the percentage: 45 out of 67
numa=45
denomi=67
percent=numa/denomi*100
print(percent)
# Out:
# 67.16417910447761

# %%
# Question 8: Find the square root of 23.456
num=23.456
root=num**0.5
print(root)
roots=25**0.5
print(roots)
# Out:
# 4.843139477652899
# 5.0

# %%
# Question 9: Calculate the simple interest: Principal=2500, Rate=6.5%, Time=2.5 years
p=2500
r=6.5  ## 6.5%
t=2.5
SI=(p*t*r)/100
print(SI)
# Out:
# 406.25

# %%
# Question 10: Convert 45.7 degrees to radians
degrees=45.7
radians_=degrees*(3.141/180)
print(radians_)

import math
degree=45.7
radians=math.radians(degree)
print(radians)
# Out:
# 0.7974650000000001
# 0.7976154681614086

# %%
word="raaju buchi"
reverse=word.reverse()

# %%
## Python Built-in Numeric Data Type
## (1)=int(integer)
## int (Integer): Represents whole numbers (positive, negative, or zero) without a fractional part.
## Explanation: Integers represent whole numbers. They are fundamental for counting, indexing, and representing discrete quantities like the number of students, courses, or batches.

# %%
## addition(+)
## adding 2 numbers
num_students=120
num_teachers=15
total=num_students+num_teachers
print(total)
# Out:
# 135

# %%
## Subtraction (-)
## subtracting the first from the second
num_teachers=15
num_students=120
diff_=num_teachers-num_students
print(diff_)
diff_1=num_students-num_teachers
print(f"different between:{diff_1}")
# Out:
# -105
# different between:105

# %%
## Multiplication (*)
## multiples the two numbers
num_teachers=15
num_students=120
multi_=num_teachers*num_students
print(multi_)
num_teachers=-15
num_students=120
neg_=num_teachers*num_students
print(neg_)
# Out:
# 1800
# -1800

# %%
## Floor Division (//)
##  Divides the first number by the second and rounds the result down to the nearest whole number (integer)
## quotient is the answer
total_students = 157
students_per_batch = 50
full_batches=total_students//students_per_batch
print(full_batches)

## Divide by large number  
producers=100
consumers=1000
result=producers//consumers
print(result)

teachers=15
students=170
get_mode=teachers//teachers
print(get_mode)
# Out:
# 3
# 0
# 1

# %%
## Modulo (%)
## it return the remainder of the division of the first number by the second.

students=159
teachers=15
results=students % teachers
print(results)

consumers=174
producers=22
remain_consumers=consumers % producers
print(remain_consumers)

student_id=1729
is_odd=student_id % 2
print(f" yes this is my id with odd:{is_odd}")  ## 1 means yes
# Out:
# 9
# 20
#  yes this is my id with odd:1

# %%
## Exponentiation(**)
## Raises thr first num to the power of second num

growth=2
periods=3
projected_students=(growth ** periods)*100
print(projected_students)

length=4
breadth=2
area=length ** breadth
print(area)

length=4
breadth=4
area=length ** breadth
print(area)

## anything power with zero,output is 1

base=-5
power=2
result=base ** power
print(result)
base=-5
power=3
result=base ** power
print(result)
# Out:
# 800
# 16
# 256
# 25
# -125

# %%
## Absolute value
## abs()...returns the absolute (non negative) value of a num

student_id=-1729
result=abs(student_id)
print(result)

length=30
breadth=15
diff_=abs(breadth - length)
print(diff_)
# Out:
# 1729
# 15

# %%
## pow(base,exp[mod])
## it returns the exponentation (x ** y)

result=pow(2,3)
print(result)

side_length=5
power=2
area=pow(side_length,power)
print(area)

## if we add modulus
side_length=5
power=3
area=pow(side_length,power,2)
print(area)
# Out:
# 8
# 25
# 1

# %%
## divmod(a,b)
## it returns the value along with the quotient(div) and remainder(mod)
total_students=146
teachers=15
results=divmod(total_students,teachers)
print(results)

assignments=47
instructors=4
assign_per=divmod(assignments,instructors)
print(assign_per)
# Out:
# (9, 11)
# (11, 3)

# %%
## int()
## while also the constructor,can be used as a function to convert the values from the other types ( like float or compatible string and boolean) to an interger.
## it avoids the decimals

avg_rating=4.5
print(int(avg_rating))

student_str="1729"
print(int(student_str))

neg_float_str="-1729"
print(int(neg_float_str))
raman=-0.1729
print(int(raman))

active_true=True
print(int(active_true))
active_false=False
print(int(active_false))
# Out:
# 4
# 1729
# -1729
# 0
# 1
# 0

# %%
## float pointing numbers
## float,it represents the values with a decimal points,not be a whole number.
## float support the same arithmetic operations(+,-,*./),but results in float.

## floor division(//) and modulus(%),this operations also work with float.(output should be absolute float value)

### if you want float values as a output you must provide input values as float.

avg_rate=4.6
total_points=1.0
result=avg_rate//total_points
print(result)
# Out:
# 4.0

# %%
## round(num , ndigits)
##  Rounds a number to a specified number of decimal places (ndigits).

avg_rating=4.45678
print(round(avg_rating))
print(round(avg_rating,0))
print(round(avg_rating,1))
print(round(avg_rating,2))
print("round")
avg_val=49.94567
print(round(avg_val))
print(round(avg_val,0))
print(round(avg_val,1))
# Out:
# 4
# 4.0
# 4.5
# 4.46
# round
# 50
# 50.0
# 49.9

# %%
## rounding to negative value
neg_val=-4.57
print(round(neg_val))
print(round(neg_val,0))
print(round(neg_val,1))
print(round(neg_val,2))
# Out:
# -5
# -5.0
# -4.6
# -4.57

# %%
## float.is_integer()
## in this function, if there is a value after the decimal point,it returns the False.
## if there is no value after the decimal,except (0),it returns the True.
avg_rating=4.8
print(avg_rating.is_integer())

avg_val=5.00
print(avg_val.is_integer())

side=10.0
length=3.0
div=side/length
print(div.is_integer())
# Out:
# False
# True
# False

# %%
## float.as_integer_ratio()
## returns the pair of integer values with in a tuple to the decimal value.

avg_rate=4.5
print(avg_rate.as_integer_ratio())

ratio=0.5
18
print(ratio.as_integer_ratio())

## for nagative
ratio_val=-4.67
print(ratio_val.as_integer_ratio())
# Out:
# (9, 2)
# (1, 2)
# (-2628976282477527, 562949953421312)

# %%
## float()
## the type constructor,can also be used as a function to convert the float from the other types(int or compatable strings).

students=1500
teachers=200
total=float(students+teachers)
print(total)

zero_=float(0)
print(zero_)

sci_str="1.54e3"
print(float(sci_str))

true="True"
print(float(true))  ##could not convert string to float: 'True
# Out:
# 1700.0
# 0.0
# 1540.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 16
#      13 print(float(sci_str))
#      15 true="True"
# ---> 16 print(float(true))
#
# ValueError: could not convert string to float: 'True'

# %%
## Text type (str)-------strings are immutable.
## strings are used to represents the textual data with in single,double and triple quotes.
## triple quotes in multiple-line strings or docstrings.
## examples
institute='sv university'
branch="science"
city='''tirupati'''

# %%
## Concatination(+)-joins 2 strings together,creating a new string.


institute="sv.university"
course="m.sc.statistics"
result=institute+" : "+course
print(result)

place="tirumala"
god="balaji"
result="welcome to "+place+" to visit "+god
print(result)
# Out:
# sv.university : m.sc.statistics
# welcome to tirumala to visit balaji

# %%
## repetition(*)-repeats the string a specified no.of times,creating a new string.
repeat="om namo venkatesaya"
result=repeat*1000
print(result)
# Out:
# om namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo venkatesayaom namo ve
# ...

# %%
## len()
## it is a function to find the length(no.of characters) in a string.
word="om namo venkatesaya"
result=len(word*1000)
print(result)
# Out:
# 19000

# %%
## indexing( [] )
## accessing a single char at a specifc position(index)
## python uses a zero based indexing(first char)
## negative indices count fron the end(-1 ,is the last char)

university="sv.university"
place="tirupathi"
result=university+" "+place
print(result)
length=len(result)
print(length)
print(result[0])
print(result[18])
print(result[-8])
# Out:
# sv.university tirupathi
# 23
# s
# p
# i

# %%
## Slicing(  [:]  )
## extracting a portion in a string using [start:stop:step]
## start-the index where the slice begins....(inclusing)
## stop-the index where the slice end.....(excluding)
## step-the increament between indices

# %%
insti="edukron"
place="bangaluru"
result=insti+" "+place
print(result)
length=len(result)
print(length)
print(result[12])
print(result[:])
print(result[8:14])
print(result[:-8])
print(result[-11:])
print(result[0:15:2])
# Out:
# edukron bangaluru
# 17
# a
# edukron bangaluru
# bangal
# edukron b
# n bangaluru
# eurnbnau

# %%
## str.upper
## returns a new string with all chars converted in upper case
university="sri venkateswara university"
result_upper=str.upper(university)*5
print(result_upper)
# Out:
# SRI VENKATESWARA UNIVERSITYSRI VENKATESWARA UNIVERSITYSRI VENKATESWARA UNIVERSITYSRI VENKATESWARA UNIVERSITYSRI VENKATESWARA UNIVERSITY

# %%
## str.lower()
## return the new string with all chars are cnverted in to lower case.
university="SRI VENKATESWARA UNIVERSITY"
result_lower=str.lower(university)
print(result_lower)
# Out:
# sri venkateswara university

# %%
## str.strip = returns the new string with leading and trailing chars removed.
## str.lstrip = return the new string,removing leading char only
## str.rstrip = return the new string,removing trailing char only

# %%
user_input = "  Data Science  "
clean_up=user_input.strip( )
print(clean_up)
# Out:
# Data Science

# %%
user_input = "  Data Science..."
clean_=user_input.lstrip()
print(clean_)
# Out:
# Data Science...

# %%
user_input = "...Data Science  "
clean_1=user_input.rstrip()
print(clean_1)

version = "v1.0.RELEASE..."
stripped_version = version.rstrip(".")
print(stripped_version)
# Out:
# ...Data Science
# v1.0.RELEASE

# %%
course_code = "===DS101==="
clean=course_code.strip("=")
print(clean)
# Out:
# DS101

# %%
## str.replace(old,new[,count])
## returns the new string where all occurrences of the substring old are replace with the substring new.

course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps and Python and SQL"
result=course_slogan.replace("Data Engineering","Data Science")
print(result)
# Out:
# Learn Data Science with Real-Time Projects

# %%
tech_stack = "Azure DevOps and Python and SQL"
result_1=tech_stack.replace("Azure","AWS")## dont forget it within strings
print(result_1)
# Out:
# AWS DevOps and Python and SQL

# %%
stock="azure devopd and data science and data engineering and jjdjsj and hdhdyd"
result_2=stock.replace("and","&",4)
print(result_2)
# Out:
# azure devopd & data science & data engineering & jjdjsj & hdhdyd

# %%
## str.split(sep=none,maxsplit=-1)
## returns a list 0f substring by spliting the string at occurrence of the separeter (sep).
## if sep is omitted or not ,split by the any white spaces char and discards empty string.
## if sep is omitted,splits exactly at that separater.
course_slogan="learn data engineering with real time projects"
word=course_slogan.split()
print(word)
word_=course_slogan.split("with")
print(word_)
words="raghavendra swamy"
print(words.split())
print(words.split("s"))
# Out:
# ['learn', 'data', 'engineering', 'with', 'real', 'time', 'projects']
# ['learn data engineering ', ' real time projects']
# ['raghavendra', 'swamy']
# ['raghavendra ', 'wamy']

# %%
## maxsplit=num
institute = "Edukron"
print(institute.split("k"))
# Out:
# ['Edu', 'ron']

# %%
## str.join(iterable)
## it is opposite of split.Takes an iterable(like a list or tuple)of strings and concatenate its elements.

course_list = ["Data Science", "Data Engineering", "Azure DevOps"]
result=" & ".join(course_list)
print(result)
separate=" | "
results=separate.join(course_list)
print(results)
new_lines="\n".join(course_list)## (\n) for new lines.
print(new_lines)
# Out:
# Data Science & Data Engineering & Azure DevOps
# Data Science | Data Engineering | Azure DevOps
# Data Science
# Data Engineering
# Azure DevOps

# %%
institute=["r","a","j","u"]
join_="".join(institute)
print(join_)
## empty list
empty_=[]
result=",".join(empty_)
print(result)
# Out:
# raju

# %%
empty_=["sbjxyasdb87","ashdbyb "]
result=",,,uygu ".join(empty_)
print(result)
# Out:
# sbjxyasdb87,,,uygu ashdbyb

# %%
## str.startswith(prefix[, start[, end]]) and str.endswith(suffix[, start[, end]])
## startwith() - return True if the string start with the specified prefix.else false.
## endswith() - return True if the string ends with the specific suffix,else false.
## prefix and suffix can also be a tuple of strings to check against.

# %%
temple="sri venkateshwara swamy"
start_with=temple.startswith("sri")
print(start_with)
start_with=temple.startswith("swamy")
print(start_with)
end_with=temple.endswith("swamy")
print(end_with)
end_with=temple.endswith("y")
print(end_with)
# Out:
# True
# False
# True
# True

# %%
info="my name is raju and iam from mantralayam kurnool"
start_=info.startswith("my","name")
print(start_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 info="my name is raju and iam from mantralayam kurnool"
# ----> 2 start_=info.startswith(".my",".nam")
#       3 print(start_)
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
## str.find(sub[, start[, end]]) and str.index(sub[, start[, end]])
##  searching for the first occurrence of the substring.
university="sri venkateswara univerty"
find_=university.find("sri")
print(find_)
find_=university.find("w")
print(find_)
find_=university.find("u")
print(find_)
find_=university.find("s",2)## for multiple chars
print(find_)
find_=university.find("h")## if not found ,it returns -1
print(find_)
# Out:
# 0
# 12
# 17
# 11
# -1

# %%
university="sri venkateswara univerty"
find_=university.index("sri")
print(find_)
find_=university.index("r")
print(find_)
find_=university.index("v")
print(find_)
find_=university.index("h")## if not found it raises error.
print(find_)
# Out:
# 0
# 1
# 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 8
#       6 find_=university.index("v")
#       7 print(find_)
# ----> 8 find_=university.index("h")
#       9 print(find_)
#
# ValueError: substring not found

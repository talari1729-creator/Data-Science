# %%
##abs(),its gives the absolute value
student_change=-44
abs_value=abs(student_change)
print(abs_value)
# Out:
# 44

# %%
score_1=51
score_2=48
diff_score=score_1-score_2
print(diff_score)
# Out:
# 3

# %%
##pow(base,exp,mod)
length=22
breadth=33
area=pow(length,breadth,6)
print(area)
# Out:
# 4

# %%
initial_students=99
growth_value=4
periods=3
projected_students=initial_students*pow(growth_value,periods)
print(projected_students)
# Out:
# 6336

# %%
base=44
results=pow(base,0,1)
print(results)
# Out:
# 0

# %%
base=-3
exponent=2
results=pow(base,exponent)
print(results)
# Out:
# 9

# %%
##divmod,gives the value of the quotient and the remaining vlaue
total_stu=175
per_batch=50
remain=divmod(total_stu,per_batch)
print(remain)
# Out:
# (3, 25)

# %%
days_elapsed=30
per_week=7
remain_days=divmod(days_elapsed,per_week)
print(remain)
# Out:
# (3, 25)

# %%
##int() also the type constructor
avg_rating=4.5
rate_int_value=int(avg_rating)
print(rate_int_value)
# Out:
# 4

# %%
total_students="15000"
students_int=int(total_students)
print(students_int)
# Out:
# 15000

# %%
neg_int="-3.3"
positive_int=int(float(neg_int))
print(positive_int)
# Out:
# -3

# %%
active_int=True
bool_int=int(bool(active_int))
print(bool_int)
# Out:
# 1

# %%
active_int=False
bool_int=int(bool(active_int))
print(bool_int)
# Out:
# 0

# %%
##float,it represents the decimal values
##arithmetic operations

# %%
##addition

score_1=52
score_2=48
add=score_1+score_2
print(add)
# Out:
# 100

# %%
##subtraction

score_1=52
score_2=48
sub=score_1-score_2
print(sub)
# Out:
# 4

# %%
## multiplication

score_1=52
score_2=48
mul=score_1-score_2
print(mul)
# Out:
# 4

# %%
## division with float
score_1=52
score_2=48
div=score_1/score_2
print(div)

score_1=52.0
score_2=48
div=score_1/score_2
print(div)

score_1=52
score_2=48.0
div=score_1/score_2
print(div)

score_1=52.0
score_2=48.0
div=score_1/score_2
print(div)
# Out:
# 1.0833333333333333
# 1.0833333333333333
# 1.0833333333333333
# 1.0833333333333333

# %%
##floor division(//) and mod(%)
avg_rates=48.0
full_points=avg_rates//5.0
print(full_points)
# Out:
# 9.0

# %%
##round values,it gives the  round values of the decimal points
##round(num,ndigit)
avg_rates=4.678
round_val=round(avg_rates,2)
print(round_val)
# Out:
# 4.68

# %%
avg_rates=1537.5
round_val=round(avg_rates,-2)
print(round_val)
# Out:
# 1500.0

# %%
##float.is_integer
## it gives the value of true or falses,which does not consist the value after the decimal


avg_rating=3.666
print(avg_rating.is_integer())

avg_rating=364646.000
print(avg_rating.is_integer())

avg_rating=-3.666
print(avg_rating.is_integer())

avg_rating=-3666.000
print(avg_rating.is_integer())
# Out:
# False
# True
# False
# True

# %%
##float.as_integer_ratio(),it gives the ratio value of the float

avg_rating=48.88
print(avg_rating.as_integer_ratio())

avg_rating=-48.88
print(avg_rating.as_integer_ratio())

avg_rating=0.5
print(avg_rating.as_integer_ratio())

avg_rating=4800.0008888
print(avg_rating.as_integer_ratio())
# Out:
# (6879248430808433, 140737488355328)
# (-6879248430808433, 140737488355328)
# (1, 2)
# (5277656790570735, 1099511627776)

# %%
##float,it gives the true or false

students="150.0"
print(float(students))

fake=True
print(float(fake))

fake=False
print(float(fake))

fake=1.6e3
print(float(fake))
# Out:
# 150.0
# 1.0
# 0.0
# 1600.0

# %%
## concatination and repetition

institute="edukron "
focus_area="data science"
print(institute+focus_area)
# Out:
# edukron data science

# %%
name="raju "
age="24"
print("my name is "+name+"and my age is "+age)
# Out:
# my name is raju and my age is 24

# %%
word=" Python "
emphasized=word*5
print(emphasized)
# Out:
#  Python  Python  Python  Python  Python

# %%
##length
## it is used to find the how many charactaristics of the given word

institute="sri venkateswara university"
length=len(institute)
print(length)
print(institute[:]*2)
# Out:
# 27
# sri venkateswara universitysri venkateswara university

# %%
e=[1,2,3]
e.append(4)
print(e)
# Out:
# [1, 2, 3, 4]

# %%
e.pop()
print(e)
# Out:
# [1, 2, 3]

# %%
## len(),is used to find the length of the string

institute="sri venkateswara university"
length=len(institute)
print(length)
empty_len=""
len_=len(empty_len)
len_
# Out:
# 27
# 0

# %%
password="Raajan@"
min_pass=9
if len(password)>min_pass:
    print(password)
else:
    print(min_pass)
# Out:
# 9

# %%
## indexing([]):Accessing a single character at a specific position
## slicing([:]):it means extracting a portion already existing string

institute="sri venkateswara university"
print(institute[11])
amma="emmotion"
length=len(amma)
print(amma[:])
print(amma[0:length+1])
print(amma[2:-2])
print("nee "+amma[2:-2]+" da")
# Out:
# s
# emmotion
# emmotion
# moti
# nee moti da

# %%
## str,lower() and str.upper()
## it is used to convert the characteristics in to upper and the lower

insti="edukron"
upper_insti=str.upper(insti)
upper_insti

name="UMA MAHESWARI"
lower_name=str.lower(name)
lower_name
# Out:
# 'uma maheswari'

# %%
## str.strip(),str.lstrip() and str.rstrip
these are used to remove the spaces/chars

course=" statistics "
print(course.strip())

leading_space="  mathematics     "
print(leading_space.lstrip())

end_space="    chemistry  "
print(end_space.rstrip())
# Out:
#   Cell In[145], line 2
#     these are used to remove the spaces/chars
#           ^
# SyntaxError: invalid syntax

# %%
leading_space="***mathematics***"
print(leading_space.lstrip('*'))
print(leading_space.rstrip('*'))

line="v2244...rrrrrr..."
print(line.rstrip("r."))
# Out:
# mathematics***
# ***mathematics
# v2244

# %%
##str.replace(old,new,count)
## it is used to replace the string

course_slogan = "Learn data and Engineering and with Real-Time Projects"
tech_stack = "Azure DevOps and Python and SQL"

new_slogan=course_slogan.replace(" data Engineering","    data Science")
new_slogan
# Out:
# 'Learn data and Engineering and with Real-Time Projects'

# %%
tech_stack
new_stack=tech_stack.replace("Asure","   cloud")
print(new_stack)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 tech_stack
#       2 new_stack=tech_stack.replace("Asure","   cloud")
#       3 print(new_stack)
#
# NameError: name 'tech_stack' is not defined

# %%
tech_stack = "Azure DevOps and Python and SQL"
new_stack=tech_stack.replace("Azure","cloud")
new_stack

# %%
slug=tech_stack.replace(" ","__")
slug

# %%
course_slogan="asugt and jau voi and hgjtj and fjtit and fjtun"
and_=course_slogan.replace("and","&",2)
and_

# %%
test=[2,3,4,5,6,7,8]
print(test)
test.clear()
test

# %%
##returns the list of sub strings by spliting the at occyrrence of thr separater sep

course_slogan = "Learn Data Engineering with Real-Time Projects"
tech_stack = "Azure DevOps,Python,SQL,Git"
institute = "Edukron"

word=course_slogan.split()
word
type(word)

# %%
tech_stack
tech_stack.split(',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 tech_stack
#       2 tech_stack.split(',')
#
# NameError: name 'tech_stack' is not defined

# %%
institute
institute.split('u')
# Out:
# ['sri venkateswara ', 'niversity']

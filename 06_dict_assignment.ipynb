# %%
# Question 1: Create a dictionary of student names and their ages
student={"name":"raajan","age":24}
print(student)
# Out:
# {'name': 'raajan', 'age': 24}

# %%
# Question 2: Add a new key-value pair to dictionary {'a': 1, 'b': 2, 'c': 3}
alpha_dict={'a': 1, 'b': 2, 'c': 3}
alpha_dict["d"]=4
print(alpha_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# Question 3: Get all keys from dictionary {'name': 'John', 'age': 25, 'city': 'New York'}
person= {'name': 'John', 'age': 25, 'city': 'New York'}
result=person.keys()
print(result)
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
# Question 4: Get all values from dictionary {'python': 3, 'java': 2, 'c++': 1}
course={'python': 3, 'java': 2, 'c++': 1}
result=course.values()
print(result)
# Out:
# dict_values([3, 2, 1])

# %%
# Question 5: Check if key 'age' exists in {'name': 'Alice', 'age': 30, 'city': 'London'}
person_={'name': 'Alice', 'age': 30, 'city': 'London'}
result_="age" in person_
print(result_)
# Out:
# True

# %%
# Question 6: Remove key 'temp' from {'a': 1, 'b': 2, 'temp': 3, 'c': 4}
dict_={'a': 1, 'b': 2, 'temp': 3, 'c': 4}
del dict_["temp"]
print(dict_)
# Out:
# {'a': 1, 'b': 2, 'c': 4}

# %%
# Question 7: Find the sum of all values in {'math': 85, 'science': 92, 'english': 78}
subjects={'math': 85, 'science': 92, 'english': 78}
result=subjects.values()
print(sum(result))
# Out:
# 255

# %%
# Question 8: Create a dictionary with squares of numbers 1 to 5
squares={}
for i in range(1,6):
    squares[i]=i**2
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# Question 9: Count frequency of each character in string "hello"
word="hello"
freq={}
for ch in word:
    freq[ch]=freq.get(ch,0)+1
print(freq)
# Out:
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
# Question 10: Merge two dictionaries {'a': 1, 'b': 2} and {'c': 3, 'd': 4}
dict_1= {'a': 1, 'b': 2}
dict_2={'c': 3, 'd': 4}
dict_1.update(dict_2)
print(dict_1)

merged={**dict_1,**dict_2}
print(merged)

merging=dict_1|dict_2
print(merging)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# Question 11: Create a nested dictionary: {'person': {'name': 'Alice', 'age': 25}}
students = {
    "student1": {
        "name": "Alice",
        "age": 25,
        "grade": "A"    # A+
    },
    "student2": {
        "name": "Bob",
        "age": 23,
        "grade": "B"
    },
    "student3": {
        "name": "Charlie",
        "age": 24,
        "grade": "A"
    }
}
print(students)
# Out:
# {'student1': {'name': 'Alice', 'age': 25, 'grade': 'A'}, 'student2': {'name': 'Bob', 'age': 23, 'grade': 'B'}, 'student3': {'name': 'Charlie', 'age': 24, 'grade': 'A'}}

# %%
# Question 12: Access nested value 'name' from {'student1': {'name': 'Alice', 'age': 25}}
students
student_name=students.get("student1").get("name")
print(student_name)
# Out:
# Alice

# %%
# Question 13: Create a dictionary with list values: {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}
fruits_data={'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}
print(fruits_data)
# Out:
# {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}

# %%
# Question 14: Add 'orange' to the 'fruits' list in nested dictionary
print(fruits_data)
fruits_data["fruits"].append("orange")
print(fruits_data)
# Out:
# {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}
# {'fruits': ['apple', 'banana', 'orange'], 'colors': ['red', 'blue']}

# %%
# Question 15: Create a dictionary with tuple values: {'coordinates': (10, 20), 'rgb': (255, 0, 0)}
my_dict={"coordinate":(10,20),
         "rgb":(255,0,0)
         }
print(my_dict)
# Out:
# {'coordinate': (10, 20), 'rgb': (255, 0, 0)}

# %%
# Question 16: Extract first coordinate from nested tuple
my_dict={"coordinate":(10,20),
         "rgb":(255,0,0)
         }
first_coordinate=my_dict["coordinate"][0]
print(first_coordinate)
first_coordinate=my_dict["rgb"][0]
print(first_coordinate)
# Out:
# 10
# 255

# %%
# Question 17: Create a dictionary with set values: {'vowels': {'a', 'e', 'i'}, 'consonants': {'b', 'c', 'd'}}
set_dict={'vowels': {'a', 'e', 'i'},
           'consonants': {'b', 'c', 'd'}
           }
print(dict(set_dict))
# Out:
# {'vowels': {'a', 'e', 'i'}, 'consonants': {'d', 'b', 'c'}}

# %%
# Question 18: Add 'o' to vowels set in nested dictionary
type(set_dict)
adding_=set_dict["vowels"].update("o")
print(set_dict)
# Out:
# {'vowels': {'a', 'o', 'e', 'i'}, 'consonants': {'d', 'b', 'c'}}

# %%
# Question 19: Create a 3-level nested dictionary: {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}
nested_dict= {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}
print(nested_dict)
# Out:
# {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}

# %%
# Question 20: Access employee name from 3-level nested dictionary
nested_dict
access_name=nested_dict["company"]["department"]["employee"]["name"]
print(access_name)
# Out:
# John

# %%
# Question 21: Create a dictionary with mixed data types: {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}
mixed_dict={'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}
print(mixed_dict)
# Out:
# {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}

# %%
# Question 22: Check data type of each value in mixed dictionary
mixed_dict
for key,value in mixed_dict.items():
    print(f"{key}:type{(value)}")
# Out:
# int:type42
# float:type3.14
# str:typehello
# bool:typeTrue

# %%
# Question 23: Create a dictionary with function values: {'len': len, 'str': str, 'int': int}
fun_dict={"len":18,
          "str":20,
          "int":48,
          }
print(fun_dict)
# Out:
# {'len': 18, 'str': 20, 'int': 48}

# %%
# Question 24: Apply each function to "123" using dictionary
function_dict={"len":" ",
               "str":" ",
               "int":" "
               }
result=dict.fromkeys(function_dict,"123")
print(result)
type(result)
# Out:
# {'len': '123', 'str': '123', 'int': '123'}
# dict

# %%
# Question 25: Create a dictionary with lambda functions: {'double': lambda x: x*2, 'square': lambda x: x**2}
lambda_dict={'double': lambda x: x*2, 'square': lambda x: x**2}

# %%
# Question 26: Apply each lambda function to 5
lambda_dict={'double': lambda x: x*2, 'square': lambda x: x**2}
for name,func in lambda_dict.items():
    result=func(5)
    print(f"{name}:{result}")
# Out:
# double:10
# square:25

# %%
for key,value in lambda_dict.items():
    result=value(8)
    print(f"{key}:{result}")
# Out:
# double:16
# square:64

# %%
# Question 29: Create a dictionary with None values: {'a': None, 'b': None, 'c': None}
none_dict={'a': None, 'b': None, 'c': None}
print(none_dict)
# Out:
# {'a': None, 'b': None, 'c': None}

# %%
# Question 30: Replace all None values with 0
none_dict={'a': None, 'b': None, 'c': None}
for key,value in none_dict.items():
    if value is None:
        none_dict[key]=0
print(none_dict)
# Out:
# {'a': 0, 'b': 0, 'c': 0}

# %%
# Question 31: Create a dictionary with boolean values: {'is_active': True, 'is_admin': False}
bool_dict={'is_active': True, 'is_admin': False}
print(bool_dict)
# Out:
# {'is_active': True, 'is_admin': False}

# %%
# Question 32: Count True values in boolean dictionary
bool_dict={'is_active': True, 
           'is_admin': False,
           "is_alpha":True,
           "is_digit":False,
           "is_name":True
           }
count_true=sum(value for value in bool_dict.values())
print(count_true)
# Out:
# 3

# %%
bool_dict={'is_active': True, 
           'is_admin': False,
           "is_alpha":True,
           "is_admin":False,
           "is_admin":True
           }
count_key=sum(key for key in bool_dict.keys())
print(count_key)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 7
#       1 bool_dict={'is_active': True,
#       2            'is_admin': False,
#       3            "is_alpha":True,
#       4            "is_admin":False,
#       5            "is_admin":True
#       6            }
# ----> 7 count_key=sum(key for key in bool_dict.keys())
#       8 print(count_key)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Question 35: Create a 4-level nested dictionary
students={
    "student_1":{"name":"raajan",
                 "age":24,
                 "gread":"A"},
    "student_2":{"name":"buchi",
                 "age":23,
                 "grwad":"A+"},
    "student_3":{"name":"ammu",
                 "age":25,
                 "gread":"A++"},
    "student_4":{"name":"nanna",
                 "age":26,
                 "gread":"A+++"}
    }
print(students)
# Out:
# {'student_1': {'name': 'raajan', 'age': 24, 'gread': 'A'}, 'student_2': {'name': 'buchi', 'age': 23, 'grwad': 'A+'}, 'student_3': {'name': 'ammu', 'age': 25, 'gread': 'A++'}, 'student_4': {'name': 'nanna', 'age': 26, 'gread': 'A+++'}}

# %%
# Question 36: Access deepest value in 4-level nested dictionary
print(students)
deep_value=students["student_4"]["gread"]
print(deep_value)
# Out:
# {'student_1': {'name': 'raajan', 'age': 24, 'gread': 'A'}, 'student_2': {'name': 'buchi', 'age': 23, 'grwad': 'A+'}, 'student_3': {'name': 'ammu', 'age': 25, 'gread': 'A++'}, 'student_4': {'name': 'nanna', 'age': 26, 'gread': 'A+++'}}
# A+++

# %%
# Question 37: Create a dictionary with range values: {'r1': range(3), 'r2': range(5)}
range_dict={'r1': range(3), 'r2': range(5)}
print(range_dict)
# Out:
# {'r1': range(0, 3), 'r2': range(0, 5)}

# %%
# Question 38: Convert each range to list
range_dict
for key,value in range_dict.items():
  print(list(value))
# Out:
# [0, 1, 2]
# [0, 1, 2, 3, 4]

# %%
  list_range={key:list(value) for key,value in range_dict.items()}
  print(list_range)
# Out:
# {'r1': [0, 1, 2], 'r2': [0, 1, 2, 3, 4]}

# %%
# Question 39: Create a dictionary with generator values
 # Question 40: Convert each generator to list
gen_dict={
    "squares":(x**2 for x in range(1,6)),
    "cube":(x**3 for x in range (1,6))
}
print(list(gen_dict["squares"]))
print(list(gen_dict["cube"]))
# Out:
# [1, 4, 9, 16, 25]
# [1, 8, 27, 64, 125]

# %%
# Question 41: Create a dictionary with iterator values
iter_dict={"numbers":iter([1,2,3,4,5]),
           "letters":iter("abcdef"),
           "range":iter(range(1,6))
           }
print(list(iter_dict["numbers"]))
print(list(iter_dict["letters"]))
print(list(iter_dict["range"]))
# Out:
# [1, 2, 3, 4, 5]
# ['a', 'b', 'c', 'd', 'e', 'f']
# [1, 2, 3, 4, 5]

# %%
# Question 42: Extract all elements from each iterator
iter_dict={"numbers":iter([1,2,3,4,5]),
           "letters":iter("abcdef"),
           "range":iter(range(1,6))
           }
list_dict={key:list(val) for key,val in iter_dict.items()}
print(list_dict)
# Out:
# {'numbers': [1, 2, 3, 4, 5], 'letters': ['a', 'b', 'c', 'd', 'e', 'f'], 'range': [1, 2, 3, 4, 5]}

# %%
# Question 43: Create a dictionary with nested lists:
nest_dict={"nums":[[1,2],[3,4]],
           "even":[[2,4],[6,8]],
           "odd":[[1,3],[5,7]]
           }
print(nest_dict)
# Out:
# {'nums': [[1, 2], [3, 4]], 'even': [[2, 4], [6, 8]], 'odd': [[1, 3], [5, 7]]}

# %%
# Question 44: Find sum of each nested list
nest_dict
sum_dict={key:sum(sum(inner)for inner in val) for key,val in nest_dict.items()}
print(sum_dict)
# Out:
# {'nums': 10, 'even': 20, 'odd': 16}

# %%
nested_dict={"nums":[[1,2,3],[3,4,5]],
           "even":[[2,4,6],[8,10,12]],
           "odd":[[1,3,5],[7,9,11]]
           }

sum_nested={key:[sum(inner)for inner in val]for key,val in nested_dict.items()}
print(sum_nested)
# Out:
# {'nums': [6, 12], 'even': [12, 30], 'odd': [9, 27]}

# %%
nested_dict
total_sum_nested={key:sum(sum(inner)for inner in val)for key,val in nested_dict.items()}
print(total_sum_nested)
print(sum([nums][even][odd]))
# Out:
# {'nums': 18, 'even': 42, 'odd': 36}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       2 total_sum_nested={key:sum(sum(inner)for inner in val)for key,val in nested_dict.items()}
#       3 print(total_sum_nested)
# ----> 4 print(sum([nums][even][odd]))
#
# NameError: name 'nums' is not defined

# %%
# Question 45: Create a dictionary with nested dictionaries
dict_nest={"nums":{"intiger":{"natural":12345}}}
print(dict_nest)
# Out:
# {'nums': {'intiger': {'natural': 12345}}}

# %%
# Question 47: Create a dictionary with nested tuples:
nest_tuple= {'points': ((1, 2), (3, 4)), 'rgb': ((255, 0, 0), (0, 255, 0))}
print(nest_tuple)
# Out:
# {'points': ((1, 2), (3, 4)), 'rgb': ((255, 0, 0), (0, 255, 0))}

# %%
# Question 49: Create a dictionary with nested sets: 
dict={
    'groups': [{1, 2, 3}, {4, 5, 6}],
    'categories': [{'a', 'b'}, {'c', 'd'}]
            }
print(dict)
# Out:
# {'groups': [{1, 2, 3}, {4, 5, 6}], 'categories': [{'a', 'b'}, {'c', 'd'}]}

# %%
nested_sets = {
    "nums": [{1, 2}, {3, 4}],
    "even": [{2, 4}, {6, 8}],
    "odd": [{1, 3}, {5, 7}]
}
print(nested_sets)
# Out:
# {'nums': [{1, 2}, {3, 4}], 'even': [{2, 4}, {8, 6}], 'odd': [{1, 3}, {5, 7}]}

# %%
# Question 50: Find union of all nested sets
nested_sets
union_set={key:set().union(*val) for key,val in nested_sets.items()}
print(union_set)
# Out:
# {'nums': {1, 2, 3, 4}, 'even': {8, 2, 4, 6}, 'odd': {1, 3, 5, 7}}
